# %% [markdown]
# ## Naive Bayes Classifier
# - probabilistic classifier
# - assumes one feature of model is independent of existence of another model
# - Bayes Theorem

# %% [markdown]
# ## Logistic Regression
# - Sigmoid Function

# %% [markdown]
# ## Linear SVM

# %% [markdown]
# TF-IDF gives higher weight to words that are important but less common across al documents

# %% [markdown]
# precision: when the model says something is spam, how often is it spam
# recall: out of all actual spam emails, how many did the model successfully catch
# f1 score: combination/ balance between precision and recall
# accuracy: out of all emails, how many emails were classified correctly

# %% [markdown]
#                  Model  Accuracy  Precision    Recall        F1
# 0          Naive Bayes  0.923671   0.995370  0.733788  0.844794
# 1  Logistic Regression  0.989372   0.976351  0.986348  0.981324
# 2           Linear SVM  0.990338   0.979661  0.986348  0.982993

# %% [markdown]
# Final choice: Linear SVM
